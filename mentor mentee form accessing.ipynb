# %%
import pandas as pd

# %%
df = pd.read_excel("Mentor Mentee List 2025.xlsx")
df

# %%
df.head()

# %%
df.columns

# %%
df.shape
# Out:
# (2618, 7)

# %%
df.columns

# %%
enrol="A20405224159"

# %%
student = df[df["Enrollment No."] == enrol]
student

# %%
enrol="A20405224247"

# %%
student = df[df["Enrollment No."] ==enrol]
student

# %%
xls = pd.ExcelFile("Mentor Mentee List 2025.xlsx")
xls.sheet_names

# %%
df = pd.read_excel("Mentor Mentee List 2025.xlsx",sheet_name="Mentor Mentee")
df.head()

# %%
df.columns = df.columns.str.strip()
df.head()

# %%
df.info()

# %%
mentor_name = "Dr.Ronak Parikh"

# %%
mentor_students = df[df['Name of Mentor'].str.strip() == mentor_name]
mentor_students
# Out:
# Empty DataFrame
# Columns: [Department, Student Name, Batch, Enrollment No., Semester, Programme, Name of Mentor]
# Index: []

# %%
pd.ExcelFile("Mentor Mentee List 2025.xlsx").sheet_names
# Out:
# ['Mentor Mentee', 'Sheet1']
