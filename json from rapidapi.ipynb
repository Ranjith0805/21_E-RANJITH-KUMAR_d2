# %%
import requests

# %%
url = "https://crypto-news51.p.rapidapi.com/api/v1/mini-crypto/prices?base_currency=USD&page=1&page_size=20"

header = {
	       'x-rapidapi-host': 'crypto-news51.p.rapidapi.com',
         'x-rapidapi-key': '59c4612fd7msh8cc9284ae3a8b65p1141a4jsndf41a0546774'
         }

# %%
response = requests.get(url,headers=header)
print("status code:", response.status_code)

# %%
data = response.json()
print(data)

# %%
import json
print(json.dumps(data,indent=4))

# %%
for item in data :
  print(item)

# %%
print(data.keys())

# %%
import pandas as pd

# %%
rows = data["results"]

# %%
df = pd.DataFrame(rows)
df

# %%
df.head()

# %%
df.sort_values(by="rank")
